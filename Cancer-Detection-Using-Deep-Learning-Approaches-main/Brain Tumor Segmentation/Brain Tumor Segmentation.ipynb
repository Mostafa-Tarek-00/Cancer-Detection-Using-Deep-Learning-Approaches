# %% [markdown]
# # import libraries

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
im_width = 256
im_height = 256

# %% [markdown]
# # **Load image's path and mask's path**

# %%
train_files = []
mask_files = glob('kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_12.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_18.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_6.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_2.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_1.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_17.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_13.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_7.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_8.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_14.tif']
# ['kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_12_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_18_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_6_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_2_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_1_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_17_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_13_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_7_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_8_mask.tif', 'kaggle_3m/TCGA_HT_7692_19960724/TCGA_HT_7692_19960724_14_mask.tif']

# %% [markdown]
# # **Data Visualization**

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# # **Create data frame and split data on train set, validation set and test set**

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %% [markdown]
# # **Data genertator, data augmentation and adjust data**

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %% [markdown]
# # **loss function and metrics**

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %% [markdown]
# # **Unet**

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 64)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36928     ['activation[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 64)         256       ['conv2d_1[0][0]']
#  Normalization)
#
#  activation_1 (Activation)   (None, 256, 256, 64)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)   (None, 128, 128, 128)        0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)        147584    ['activation_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 128)        512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)   (None, 64, 64, 256)          0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)          590080    ['activation_4[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 512)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 512)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 512)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 1024)         0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 1024)         9438208   ['activation_8[0][0]']
#
#  batch_normalization_4 (Bat  (None, 16, 16, 1024)         4096      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 1024)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 512)          2097664   ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 1024)         0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 512)          4719104   ['concatenate[0][0]']
#
#  activation_10 (Activation)  (None, 32, 32, 512)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_10[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 512)          2048      ['conv2d_11[0][0]']
#  chNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 256)          524544    ['activation_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate_1[0][0]']
#
#  activation_12 (Activation)  (None, 64, 64, 256)          0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_12[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64, 64, 256)          1024      ['conv2d_13[0][0]']
#  chNormalization)
#
#  activation_13 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 128)        131200    ['activation_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_2[0][0]']
#
#  activation_14 (Activation)  (None, 128, 128, 128)        0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_14[0][0]']
#
#  batch_normalization_7 (Bat  (None, 128, 128, 128)        512       ['conv2d_15[0][0]']
#  chNormalization)
#
#  activation_15 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 64)         32832     ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_3[0][0]']
#
#  activation_16 (Activation)  (None, 256, 256, 64)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_16[0][0]']
#
#  batch_normalization_8 (Bat  (None, 256, 256, 64)         256       ['conv2d_17[0][0]']
#  chNormalization)
#
#  activation_17 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 1)          65        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31043521 (118.42 MB)
# Trainable params: 31037633 (118.40 MB)
# Non-trainable params: 5888 (23.00 KB)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model

model = unet()

plot_model(model, to_file='unet_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # **Training**

# %%
EPOCHS = 150
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = unet(input_size=(im_height, im_width, 3))



decay_rate = learning_rate / EPOCHS
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/150
# 89/88 [==============================] - ETA: 0s - loss: -0.1253 - binary_accuracy: 0.9374 - iou: 0.0683 - dice_coef: 0.1255Found 708 validated image filenames.
# Found 708 validated image filenames.
#
# Epoch 00001: val_loss improved from inf to -0.02246, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 103s 1s/step - loss: -0.1253 - binary_accuracy: 0.9374 - iou: 0.0683 - dice_coef: 0.1255 - val_loss: -0.0225 - val_binary_accuracy: 0.9884 - val_iou: 0.0110 - val_dice_coef: 0.0216
# Epoch 2/150
# 89/88 [==============================] - ETA: 0s - loss: -0.2186 - binary_accuracy: 0.9860 - iou: 0.1245 - dice_coef: 0.2189
# Epoch 00002: val_loss did not improve from -0.02246
# 89/88 [==============================] - 69s 777ms/step - loss: -0.2186 - binary_accuracy: 0.9860 - iou: 0.1245 - dice_coef: 0.2189 - val_loss: -0.0197 - val_binary_accuracy: 0.9897 - val_iou: 0.0102 - val_dice_coef: 0.0198
# Epoch 3/150
# 89/88 [==============================] - ETA: 0s - loss: -0.2700 - binary_accuracy: 0.9897 - iou: 0.1596 - dice_coef: 0.2711
# Epoch 00003: val_loss improved from -0.02246 to -0.07773, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 790ms/step - loss: -0.2700 - binary_accuracy: 0.9897 - iou: 0.1596 - dice_coef: 0.2711 - val_loss: -0.0777 - val_binary_accuracy: 0.9705 - val_iou: 0.0398 - val_dice_coef: 0.0754
# Epoch 4/150
# 89/88 [==============================] - ETA: 0s - loss: -0.3269 - binary_accuracy: 0.9917 - iou: 0.1983 - dice_coef: 0.3264
# Epoch 00004: val_loss improved from -0.07773 to -0.09354, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 71s 796ms/step - loss: -0.3269 - binary_accuracy: 0.9917 - iou: 0.1983 - dice_coef: 0.3264 - val_loss: -0.0935 - val_binary_accuracy: 0.9481 - val_iou: 0.0482 - val_dice_coef: 0.0904
# Epoch 5/150
# 89/88 [==============================] - ETA: 0s - loss: -0.3936 - binary_accuracy: 0.9929 - iou: 0.2484 - dice_coef: 0.3937
# Epoch 00005: val_loss improved from -0.09354 to -0.23817, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 787ms/step - loss: -0.3936 - binary_accuracy: 0.9929 - iou: 0.2484 - dice_coef: 0.3937 - val_loss: -0.2382 - val_binary_accuracy: 0.9758 - val_iou: 0.1328 - val_dice_coef: 0.2296
# Epoch 6/150
# 89/88 [==============================] - ETA: 0s - loss: -0.4608 - binary_accuracy: 0.9943 - iou: 0.3035 - dice_coef: 0.4591
# Epoch 00006: val_loss improved from -0.23817 to -0.44469, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 786ms/step - loss: -0.4608 - binary_accuracy: 0.9943 - iou: 0.3035 - dice_coef: 0.4591 - val_loss: -0.4447 - val_binary_accuracy: 0.9940 - val_iou: 0.2923 - val_dice_coef: 0.4428
# Epoch 7/150
# 89/88 [==============================] - ETA: 0s - loss: -0.5225 - binary_accuracy: 0.9950 - iou: 0.3596 - dice_coef: 0.5211
# Epoch 00007: val_loss improved from -0.44469 to -0.57478, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 789ms/step - loss: -0.5225 - binary_accuracy: 0.9950 - iou: 0.3596 - dice_coef: 0.5211 - val_loss: -0.5748 - val_binary_accuracy: 0.9957 - val_iou: 0.4112 - val_dice_coef: 0.5778
# Epoch 8/150
# 89/88 [==============================] - ETA: 0s - loss: -0.5709 - binary_accuracy: 0.9951 - iou: 0.4059 - dice_coef: 0.5705
# Epoch 00008: val_loss did not improve from -0.57478
150
# 89/88 [==============================] - ETA: 0s - loss: -0.8679 - binary_accuracy: 0.9976 - iou: 0.7714 - dice_coef: 0.8678
# Epoch 00039: val_loss did not improve from -0.86680
# 89/88 [==============================] - 69s 779ms/step - loss: -0.8679 - binary_accuracy: 0.9976 - iou: 0.7714 - dice_coef: 0.8678 - val_loss: -0.8635 - val_binary_accuracy: 0.9975 - val_iou: 0.7665 - val_dice_coef: 0.8658
# Epoch 40/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8650 - binary_accuracy: 0.9976 - iou: 0.7666 - dice_coef: 0.8631
# Epoch 00040: val_loss did not improve from -0.86680
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8650 - binary_accuracy: 0.9976 - iou: 0.7666 - dice_coef: 0.8631 - val_loss: -0.7973 - val_binary_accuracy: 0.9963 - val_iou: 0.6748 - val_dice_coef: 0.8017
# Epoch 41/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8605 - binary_accuracy: 0.9973 - iou: 0.7638 - dice_coef: 0.8607
# Epoch 00041: val_loss did not improve from -0.86680
# 89/88 [==============================] - 70s 781ms/step - loss: -0.8605 - binary_accuracy: 0.9973 - iou: 0.7638 - dice_coef: 0.8607 - val_loss: -0.8637 - val_binary_accuracy: 0.9974 - val_iou: 0.7463 - val_dice_coef: 0.8477
# Epoch 42/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8425 - binary_accuracy: 0.9972 - iou: 0.7374 - dice_coef: 0.8430
# Epoch 00042: val_loss did not improve from -0.86680
# 89/88 [==============================] - 69s 781ms/step - loss: -0.8425 - binary_accuracy: 0.9972 - iou: 0.7374 - dice_coef: 0.8430 - val_loss: -0.8632 - val_binary_accuracy: 0.9973 - val_iou: 0.7538 - val_dice_coef: 0.8558
# Epoch 43/150
# 89/88 [==============================] - ETA: 0s - loss: -0.0498 - binary_accuracy: 0.9787 - iou: 0.0273 - dice_coef: 0.0498
# Epoch 00043: val_loss did not improve from -0.86680
# 89/88 [==============================] - 70s 786ms/step - loss: -0.0498 - binary_accuracy: 0.9787 - iou: 0.0273 - dice_coef: 0.0498 - val_loss: -0.2815 - val_binary_accuracy: 0.9550 - val_iou: 0.1674 - val_dice_coef: 0.2827
# Epoch 44/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8529 - binary_accuracy: 0.9970 - iou: 0.7489 - dice_coef: 0.8527
# Epoch 00044: val_loss did not improve from -0.86680
# 89/88 [==============================] - 69s 775ms/step - loss: -0.8529 - binary_accuracy: 0.9970 - iou: 0.7489 - dice_coef: 0.8527 - val_loss: -0.8649 - val_binary_accuracy: 0.9974 - val_iou: 0.7666 - val_dice_coef: 0.8657
# Epoch 45/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8586 - binary_accuracy: 0.9974 - iou: 0.7578 - dice_coef: 0.8589
# Epoch 00045: val_loss did not improve from -0.86680
# 89/88 [==============================] - 70s 792ms/step - loss: -0.8586 - binary_accuracy: 0.9974 - iou: 0.7578 - dice_coef: 0.8589 - val_loss: -0.8438 - val_binary_accuracy: 0.9972 - val_iou: 0.7127 - val_dice_coef: 0.8149
# Epoch 46/150
# 89/88 [==============================] - ETA: 0s - loss: -0.
150
# 89/88 [==============================] - ETA: 0s - loss: -0.8732 - binary_accuracy: 0.9978 - iou: 0.7840 - dice_coef: 0.8737
# Epoch 00054: val_loss did not improve from -0.87416
# 89/88 [==============================] - 69s 778ms/step - loss: -0.8732 - binary_accuracy: 0.9978 - iou: 0.7840 - dice_coef: 0.8737 - val_loss: -0.8720 - val_binary_accuracy: 0.9976 - val_iou: 0.7824 - val_dice_coef: 0.8751
# Epoch 55/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8811 - binary_accuracy: 0.9978 - iou: 0.7940 - dice_coef: 0.8817
# Epoch 00055: val_loss did not improve from -0.87416
# 89/88 [==============================] - 70s 782ms/step - loss: -0.8811 - binary_accuracy: 0.9978 - iou: 0.7940 - dice_coef: 0.8817 - val_loss: -0.8701 - val_binary_accuracy: 0.9975 - val_iou: 0.7778 - val_dice_coef: 0.8729
# Epoch 56/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8806 - binary_accuracy: 0.9978 - iou: 0.7947 - dice_coef: 0.8809
# Epoch 00056: val_loss did not improve from -0.87416
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8806 - binary_accuracy: 0.9978 - iou: 0.7947 - dice_coef: 0.8809 - val_loss: -0.8714 - val_binary_accuracy: 0.9976 - val_iou: 0.7808 - val_dice_coef: 0.8724
# Epoch 57/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8785 - binary_accuracy: 0.9977 - iou: 0.7902 - dice_coef: 0.8788
# Epoch 00057: val_loss improved from -0.87416 to -0.87496, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 71s 794ms/step - loss: -0.8785 - binary_accuracy: 0.9977 - iou: 0.7902 - dice_coef: 0.8788 - val_loss: -0.8750 - val_binary_accuracy: 0.9976 - val_iou: 0.7895 - val_dice_coef: 0.8783
# Epoch 58/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8764 - binary_accuracy: 0.9977 - iou: 0.7843 - dice_coef: 0.8765
# Epoch 00058: val_loss did not improve from -0.87496
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8764 - binary_accuracy: 0.9977 - iou: 0.7843 - dice_coef: 0.8765 - val_loss: -0.8709 - val_binary_accuracy: 0.9974 - val_iou: 0.7801 - val_dice_coef: 0.8733
# Epoch 59/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8668 - binary_accuracy: 0.9976 - iou: 0.7700 - dice_coef: 0.8661
# Epoch 00059: val_loss did not improve from -0.87496
# 89/88 [==============================] - 69s 774ms/step - loss: -0.8668 - binary_accuracy: 0.9976 - iou: 0.7700 - dice_coef: 0.8661 - val_loss: -0.8584 - val_binary_accuracy: 0.9971 - val_iou: 0.7581 - val_dice_coef: 0.8592
# Epoch 60/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8293 - binary_accuracy: 0.9966 - iou: 0.7182 - dice_coef: 0.8302
# Epoch 00060: val_loss did not improve from -0.87496
# 89/88 [==============================] - 70s 790ms/step - loss: -0.8293 - binary_accuracy: 0.9966 - iou: 0.7182 - dice_coef: 0.8302 - val_loss: -0.8576 - val_binary_accuracy: 0.9974 - val_iou: 0.7447 - val_dice_coef: 0.8425
# Epoch 61/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8599 - binary_accuracy: 0.9974 - iou: 0.7626 - dice_coef: 0.8603
# Epoch 00061: val_loss did not improve from -0.87496
# 89/88 [==============================] - 69s 778ms/step - loss: -0.8599 - binary_accuracy: 0.9974 - iou: 0.7626 - dice_coef: 0.8603 - val_loss: -0.8504 - val_binary_accuracy: 0.9971 - val_iou: 0.7336 - val_dice_coef: 0.8346
# Epoch 62/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8751 - binary_accuracy: 0.9976 - iou: 0.7855 - dice_coef: 0.8755
# Epoch 00062: val_loss did not improve from -0.87496
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8751 - binary_accuracy: 0.9976 - iou: 0.7855 - dice_coef: 0.8755 - val_loss: -0.8487 - val_binary_accuracy: 0.9973 - val_iou: 0.7461 - val_dice_coef: 0.8522
# Epoch 63/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8742 - binary_accuracy: 0.9975 - iou: 0.7822 - dice_coef: 0.8738
# Epoch 00063: val_loss did not improve from -0.87496
# 89/88 [==============================] - 70s 784ms/step - loss: -0.8742 - binary_accuracy: 0.9975 - iou: 0.7822 - dice_coef: 0.8738 - val_loss: -0.8707 - val_binary_accuracy: 0.9972 - val_iou: 0.7569 - val_dice_coef: 0.8550
# Epoch 64/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8802 - binary_accuracy: 0.9978 - iou: 0.7888 - dice_coef: 0.8793
# Epoch 00064: val_loss improved from -0.87496 to -0.88358, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 71s 796ms/step - loss: -0.8802 - binary_accuracy: 0.9978 - iou: 0.7888 - dice_coef: 0.8793 - val_loss: -0.8836 - val_binary_accuracy: 0.9977 - val_iou: 0.7992 - val_dice_coef: 0.8853
# Epoch 65/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8807 - binary_accuracy: 0.9977 - iou: 0.7912 - dice_coef: 0.8799
# Epoch 00065: val_loss did not improve from -0.88358
# 89/88 [==============================] - 70s 784ms/step - loss: -0.8807 - binary_accuracy: 0.9977 - iou: 0.7912 - dice_coef: 0.8799 - val_loss: -0.8803 - val_binary_accuracy: 0.9975 - val_iou: 0.7958 - val_dice_coef: 0.8829
# Epoch 66/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8776 - binary_accuracy: 0.9977 - iou: 0.7875 - dice_coef: 0.8776
# Epoch 00066: val_loss did not improve from -0.88358
# 89/88 [==============================] - 69s 778ms/step - loss: -0.8776 - binary_accuracy: 0.9977 - iou: 0.7875 - dice_coef: 0.8776 - val_loss: -0.8051 - val_binary_accuracy: 0.9965 - val_iou: 0.6827 - val_dice_coef: 0.8078
# Epoch 67/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8747 - binary_accuracy: 0.9977 - iou: 0.7814 - dice_coef: 0.8739
# Epoch 00067: val_loss did not improve from -0.88358
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8747 - binary_accuracy: 0.9977 - iou: 0.7814 - dice_coef: 0.8739 - val_loss: -0.8705 - val_binary_accuracy: 0.9975 - val_iou: 0.7809 - val_dice_coef: 0.8725
# Epoch 68/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8785 - binary_accuracy: 0.9977 - iou: 0.7923 - dice_coef: 0.8791
# Epoch 00068: val_loss did not improve from -0.88358
# 89/88 [==============================] - 69s 777ms/step - loss: -0.8785 - binary_accuracy: 0.9977 - iou: 0.7923 - dice_coef: 0.8791 - val_loss: -0.8778 - val_binary_accuracy: 0.9975 - val_iou: 0.7860 - val_dice_coef: 0.8790
# Epoch 69/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8820 - binary_accuracy: 0.9978 - iou: 0.7945 - dice_coef: 0.8817
# Epoch 00069: val_loss did not improve from -0.88358
# 89/88 [==============================] - 69s 777ms/step - loss: -0.8820 - binary_accuracy: 0.9978 - iou: 0.7945 - dice_coef: 0.8817 - val_loss: -0.8737 - val_binary_accuracy: 0.9975 - val_iou: 0.7757 - val_dice_coef: 0.8711
# Epoch 70/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8884 - binary_accuracy: 0.9979 - iou: 0.8037 - dice_coef: 0.8886
# Epoch 00070: val_loss did not improve from -0.88358
# 89/88 [==============================] - 70s 785ms/step - loss: -0.8884 - binary_accuracy: 0.9979 - iou: 0.8037 - dice_coef: 0.8886 - val_loss: -0.8768 - val_binary_accuracy: 0.9976 - val_iou: 0.7769 - val_dice_coef: 0.8719
# Epoch 71/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8793 - binary_accuracy: 0.9977 - iou: 0.7907 - dice_coef: 0.8786
# Epoch 00071: val_loss did not improve from -0.88358
# 89/88 [==============================] - 69s 779ms/step - loss: -0.8793 - binary_accuracy: 0.9977 - iou: 0.7907 - dice_coef: 0.8786 - val_loss: -0.8714 - val_binary_accuracy: 0.9975 - val_iou: 0.7727 - val_dice_coef: 0.8684
# Epoch 72/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8868 - binary_accuracy: 0.9978 - iou: 0.8021 - dice_coef: 0.8871
# Epoch 00072: val_loss did not improve from -0.88358
# 89/88 [==============================] - 69s 778ms/step - loss: -0.8868 - binary_accuracy: 0.9978 - iou: 0.8021 - dice_coef: 0.8871 - val_loss: -0.8680 - val_binary_accuracy: 0.9974 - val_iou: 0.7801 - val_dice_coef: 0.8713
# Epoch 73/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8904 - binary_accuracy: 0.9979 - iou: 0.8086 - dice_coef: 0.8909
# Epoch 00073: val_loss did not improve from -0.88358
# 89/88 [==============================] - 69s 780ms/step - loss: -0.8904 - binary_accuracy: 0.9979 - iou: 0.8086 - dice_coef: 0.8909 - val_loss: -0.8797 - val_binary_accuracy: 0.9977 - val_iou: 0.7963 - val_dice_coef: 0.8826
# Epoch 74/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8883 - binary_accuracy: 0.9979 - iou: 0.8041 - dice_coef: 0.8883
# Epoch 00074: val_loss did not improve from -0.88358
# 89/88 [==============================] - 70s 788ms/step - loss: -0.8883 - binary_accuracy: 0.9979 - iou: 0.8041 - dice_coef: 0.8883 - val_loss: -0.8800 - val_binary_accuracy: 0.9976 - val_iou: 0.7924 - val_dice_coef: 0.8820
# Epoch 75/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8842 - binary_accuracy: 0.9979 - iou: 0.7974 - dice_coef: 0.8843
# Epoch 00075: val_loss did not improve from -0.88358
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8842 - binary_accuracy: 0.9979 - iou: 0.7974 - dice_coef: 0.8843 - val_loss: -0.8751 - val_binary_accuracy: 0.9975 - val_iou: 0.7717 - val_dice_coef: 0.8610
# Epoch 76/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8843 - binary_accuracy: 0.9979 - iou: 0.8002 - dice_coef: 0.8847
# Epoch 00076: val_loss improved from -0.88358 to -0.88747, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 789ms/step - loss: -0.8843 - binary_accuracy: 0.9979 - iou: 0.8002 - dice_coef: 0.8847 - val_loss: -0.8875 - val_binary_accuracy: 0.9977 - val_iou: 0.8033 - val_dice_coef: 0.8895
# Epoch 77/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8917 - binary_accuracy: 0.9979 - iou: 0.8083 - dice_coef: 0.8916
# Epoch 00077: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 782ms/step - loss: -0.8917 - binary_accuracy: 0.9979 - iou: 0.8083 - dice_coef: 0.8916 - val_loss: -0.8851 - val_binary_accuracy: 0.9979 - val_iou: 0.7988 - val_dice_coef: 0.8863
# Epoch 78/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8915 - binary_accuracy: 0.9980 - iou: 0.8079 - dice_coef: 0.8906
# Epoch 00078: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 785ms/step - loss: -0.8915 - binary_accuracy: 0.9980 - iou: 0.8079 - dice_coef: 0.8906 - val_loss: -0.8814 - val_binary_accuracy: 0.9977 - val_iou: 0.7940 - val_dice_coef: 0.8833
# Epoch 79/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8917 - binary_accuracy: 0.9979 - iou: 0.8074 - dice_coef: 0.8912
# Epoch 00079: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 784ms/step - loss: -0.8917 - binary_accuracy: 0.9979 - iou: 0.8074 - dice_coef: 0.8912 - val_loss: -0.8644 - val_binary_accuracy: 0.9975 - val_iou: 0.7648 - val_dice_coef: 0.8629
# Epoch 80/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8900 - binary_accuracy: 0.9979 - iou: 0.8066 - dice_coef: 0.8891
# Epoch 00080: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 785ms/step - loss: -0.8900 - binary_accuracy: 0.9979 - iou: 0.8066 - dice_coef: 0.8891 - val_loss: -0.8841 - val_binary_accuracy: 0.9979 - val_iou: 0.7970 - val_dice_coef: 0.8845
# Epoch 81/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8878 - binary_accuracy: 0.9979 - iou: 0.8051 - dice_coef: 0.8881
# Epoch 00081: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 782ms/step - loss: -0.8878 - binary_accuracy: 0.9979 - iou: 0.8051 - dice_coef: 0.8881 - val_loss: -0.8617 - val_binary_accuracy: 0.9971 - val_iou: 0.7659 - val_dice_coef: 0.8648
# Epoch 82/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8857 - binary_accuracy: 0.9978 - iou: 0.8016 - dice_coef: 0.8857
# Epoch 00082: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8857 - binary_accuracy: 0.9978 - iou: 0.8016 - dice_coef: 0.8857 - val_loss: -0.8850 - val_binary_accuracy: 0.9979 - val_iou: 0.8040 - val_dice_coef: 0.8885
# Epoch 83/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8835 - binary_accuracy: 0.9977 - iou: 0.7982 - dice_coef: 0.8832
# Epoch 00083: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 781ms/step - loss: -0.8835 - binary_accuracy: 0.9977 - iou: 0.7982 - dice_coef: 0.8832 - val_loss: -0.7658 - val_binary_accuracy: 0.9949 - val_iou: 0.6202 - val_dice_coef: 0.7576
# Epoch 84/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8696 - binary_accuracy: 0.9976 - iou: 0.7789 - dice_coef: 0.8697
# Epoch 00084: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 780ms/step - loss: -0.8696 - binary_accuracy: 0.9976 - iou: 0.7789 - dice_coef: 0.8697 - val_loss: -0.8784 - val_binary_accuracy: 0.9972 - val_iou: 0.7925 - val_dice_coef: 0.8819
# Epoch 85/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8873 - binary_accuracy: 0.9979 - iou: 0.8039 - dice_coef: 0.8864
# Epoch 00085: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 780ms/step - loss: -0.8873 - binary_accuracy: 0.9979 - iou: 0.8039 - dice_coef: 0.8864 - val_loss: -0.8734 - val_binary_accuracy: 0.9978 - val_iou: 0.7855 - val_dice_coef: 0.8764
# Epoch 86/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8807 - binary_accuracy: 0.9977 - iou: 0.7938 - dice_coef: 0.8808
# Epoch 00086: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 786ms/step - loss: -0.8807 - binary_accuracy: 0.9977 - iou: 0.7938 - dice_coef: 0.8808 - val_loss: -0.8761 - val_binary_accuracy: 0.9975 - val_iou: 0.7900 - val_dice_coef: 0.8800
# Epoch 87/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8847 - binary_accuracy: 0.9978 - iou: 0.8008 - dice_coef: 0.8852
# Epoch 00087: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 780ms/step - loss: -0.8847 - binary_accuracy: 0.9978 - iou: 0.8008 - dice_coef: 0.8852 - val_loss: -0.8730 - val_binary_accuracy: 0.9977 - val_iou: 0.7851 - val_dice_coef: 0.8765
# Epoch 88/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8793 - binary_accuracy: 0.9977 - iou: 0.7926 - dice_coef: 0.8795
# Epoch 00088: val_loss did not improve from -0.88747
# 89/88 [==============================] - 70s 783ms/step - loss: -0.8793 - binary_accuracy: 0.9977 - iou: 0.7926 - dice_coef: 0.8795 - val_loss: -0.8794 - val_binary_accuracy: 0.9976 - val_iou: 0.7950 - val_dice_coef: 0.8832
# Epoch 89/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8861 - binary_accuracy: 0.9980 - iou: 0.8063 - dice_coef: 0.8866
# Epoch 00089: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 778ms/step - loss: -0.8861 - binary_accuracy: 0.9980 - iou: 0.8063 - dice_coef: 0.8866 - val_loss: -0.8636 - val_binary_accuracy: 0.9976 - val_iou: 0.7720 - val_dice_coef: 0.8648
# Epoch 90/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8904 - binary_accuracy: 0.9980 - iou: 0.8082 - dice_coef: 0.8905
# Epoch 00090: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 779ms/step - loss: -0.8904 - binary_accuracy: 0.9980 - iou: 0.8082 - dice_coef: 0.8905 - val_loss: -0.8430 - val_binary_accuracy: 0.9973 - val_iou: 0.7440 - val_dice_coef: 0.8467
# Epoch 91/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8803 - binary_accuracy: 0.9977 - iou: 0.7953 - dice_coef: 0.8808
# Epoch 00091: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 779ms/step - loss: -0.8803 - binary_accuracy: 0.9977 - iou: 0.7953 - dice_coef: 0.8808 - val_loss: -0.8426 - val_binary_accuracy: 0.9970 - val_iou: 0.7427 - val_dice_coef: 0.8469
# Epoch 92/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8738 - binary_accuracy: 0.9976 - iou: 0.7813 - dice_coef: 0.8739
# Epoch 00092: val_loss did not improve from -0.88747
# 89/88 [==============================] - 68s 769ms/step - loss: -0.8738 - binary_accuracy: 0.9976 - iou: 0.7813 - dice_coef: 0.8739 - val_loss: -0.8159 - val_binary_accuracy: 0.9963 - val_iou: 0.7091 - val_dice_coef: 0.8212
# Epoch 93/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8781 - binary_accuracy: 0.9977 - iou: 0.7908 - dice_coef: 0.8785
# Epoch 00093: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 774ms/step - loss: -0.8781 - binary_accuracy: 0.9977 - iou: 0.7908 - dice_coef: 0.8785 - val_loss: -0.8665 - val_binary_accuracy: 0.9975 - val_iou: 0.7789 - val_dice_coef: 0.8709
# Epoch 94/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8894 - binary_accuracy: 0.9979 - iou: 0.8066 - dice_coef: 0.8900
# Epoch 00094: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 772ms/step - loss: -0.8894 - binary_accuracy: 0.9979 - iou: 0.8066 - dice_coef: 0.8900 - val_loss: -0.8776 - val_binary_accuracy: 0.9977 - val_iou: 0.7897 - val_dice_coef: 0.8800
# Epoch 95/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8937 - binary_accuracy: 0.9980 - iou: 0.8120 - dice_coef: 0.8937
# Epoch 00095: val_loss did not improve from -0.88747
# 89/88 [==============================] - 68s 770ms/step - loss: -0.8937 - binary_accuracy: 0.9980 - iou: 0.8120 - dice_coef: 0.8937 - val_loss: -0.8857 - val_binary_accuracy: 0.9977 - val_iou: 0.7955 - val_dice_coef: 0.8847
# Epoch 96/150
# 89/88 [==============================] - ETA: 0s - loss: -0.1778 - binary_accuracy: 0.9832 - iou: 0.1102 - dice_coef: 0.1767
# Epoch 00096: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 777ms/step - loss: -0.1778 - binary_accuracy: 0.9832 - iou: 0.1102 - dice_coef: 0.1767 - val_loss: -0.8394 - val_binary_accuracy: 0.9965 - val_iou: 0.7309 - val_dice_coef: 0.8427
# Epoch 97/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8843 - binary_accuracy: 0.9977 - iou: 0.7977 - dice_coef: 0.8846
# Epoch 00097: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 774ms/step - loss: -0.8843 - binary_accuracy: 0.9977 - iou: 0.7977 - dice_coef: 0.8846 - val_loss: -0.8635 - val_binary_accuracy: 0.9974 - val_iou: 0.7709 - val_dice_coef: 0.8675
# Epoch 98/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8739 - binary_accuracy: 0.9976 - iou: 0.7820 - dice_coef: 0.8741
# Epoch 00098: val_loss did not improve from -0.88747
# 89/88 [==============================] - 69s 780ms/step - loss: -0.8739 - binary_accuracy: 0.9976 - iou: 0.7820 - dice_coef: 0.8741 - val_loss: -0.8563 - val_binary_accuracy: 0.9975 - val_iou: 0.7596 - val_dice_coef: 0.8571
# Epoch 99/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8825 - binary_accuracy: 0.9978 - iou: 0.7961 - dice_coef: 0.8828
# Epoch 00099: val_loss improved from -0.88747 to -0.89606, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 781ms/step - loss: -0.8825 - binary_accuracy: 0.9978 - iou: 0.7961 - dice_coef: 0.8828 - val_loss: -0.8961 - val_binary_accuracy: 0.9978 - val_iou: 0.8097 - val_dice_coef: 0.8930
# Epoch 100/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8878 - binary_accuracy: 0.9979 - iou: 0.8049 - dice_coef: 0.8879
# Epoch 00100: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 774ms/step - loss: -0.8878 - binary_accuracy: 0.9979 - iou: 0.8049 - dice_coef: 0.8879 - val_loss: -0.8178 - val_binary_accuracy: 0.9967 - val_iou: 0.7046 - val_dice_coef: 0.8193
# Epoch 101/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8709 - binary_accuracy: 0.9977 - iou: 0.7827 - dice_coef: 0.8714
# Epoch 00101: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 771ms/step - loss: -0.8709 - binary_accuracy: 0.9977 - iou: 0.7827 - dice_coef: 0.8714 - val_loss: -0.8755 - val_binary_accuracy: 0.9975 - val_iou: 0.7869 - val_dice_coef: 0.8783
# Epoch 102/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8924 - binary_accuracy: 0.9979 - iou: 0.8123 - dice_coef: 0.8928
# Epoch 00102: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 770ms/step - loss: -0.8924 - binary_accuracy: 0.9979 - iou: 0.8123 - dice_coef: 0.8928 - val_loss: -0.8784 - val_binary_accuracy: 0.9975 - val_iou: 0.7816 - val_dice_coef: 0.8749
# Epoch 103/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8930 - binary_accuracy: 0.9980 - iou: 0.8134 - dice_coef: 0.8936
# Epoch 00103: val_loss did not improve from -0.89606
# 89/88 [==============================] - 68s 768ms/step - loss: -0.8930 - binary_accuracy: 0.9980 - iou: 0.8134 - dice_coef: 0.8936 - val_loss: -0.8922 - val_binary_accuracy: 0.9981 - val_iou: 0.8094 - val_dice_coef: 0.8929
# Epoch 104/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9003 - binary_accuracy: 0.9981 - iou: 0.8239 - dice_coef: 0.9006
# Epoch 00104: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 774ms/step - loss: -0.9003 - binary_accuracy: 0.9981 - iou: 0.8239 - dice_coef: 0.9006 - val_loss: -0.8911 - val_binary_accuracy: 0.9978 - val_iou: 0.8059 - val_dice_coef: 0.8911
# Epoch 105/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8941 - binary_accuracy: 0.9980 - iou: 0.8149 - dice_coef: 0.8944
# Epoch 00105: val_loss did not improve from -0.89606
# 89/88 [==============================] - 68s 768ms/step - loss: -0.8941 - binary_accuracy: 0.9980 - iou: 0.8149 - dice_coef: 0.8944 - val_loss: -0.8845 - val_binary_accuracy: 0.9977 - val_iou: 0.7804 - val_dice_coef: 0.8637
# Epoch 106/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8935 - binary_accuracy: 0.9979 - iou: 0.8141 - dice_coef: 0.8937
# Epoch 00106: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 774ms/step - loss: -0.8935 - binary_accuracy: 0.9979 - iou: 0.8141 - dice_coef: 0.8937 - val_loss: -0.8890 - val_binary_accuracy: 0.9979 - val_iou: 0.8037 - val_dice_coef: 0.8900
# Epoch 107/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8920 - binary_accuracy: 0.9980 - iou: 0.8109 - dice_coef: 0.8917
# Epoch 00107: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 773ms/step - loss: -0.8920 - binary_accuracy: 0.9980 - iou: 0.8109 - dice_coef: 0.8917 - val_loss: -0.8267 - val_binary_accuracy: 0.9966 - val_iou: 0.6987 - val_dice_coef: 0.8168
# Epoch 108/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8922 - binary_accuracy: 0.9979 - iou: 0.8087 - dice_coef: 0.8915
# Epoch 00108: val_loss did not improve from -0.89606
# 89/88 [==============================] - 70s 784ms/step - loss: -0.8922 - binary_accuracy: 0.9979 - iou: 0.8087 - dice_coef: 0.8915 - val_loss: -0.8854 - val_binary_accuracy: 0.9978 - val_iou: 0.7896 - val_dice_coef: 0.8794
# Epoch 109/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8873 - binary_accuracy: 0.9978 - iou: 0.8038 - dice_coef: 0.8876
# Epoch 00109: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 775ms/step - loss: -0.8873 - binary_accuracy: 0.9978 - iou: 0.8038 - dice_coef: 0.8876 - val_loss: -0.8957 - val_binary_accuracy: 0.9978 - val_iou: 0.7947 - val_dice_coef: 0.8795
# Epoch 110/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8888 - binary_accuracy: 0.9979 - iou: 0.8053 - dice_coef: 0.8888
# Epoch 00110: val_loss did not improve from -0.89606
# 89/88 [==============================] - 69s 773ms/step - loss: -0.8888 - binary_accuracy: 0.9979 - iou: 0.8053 - dice_coef: 0.8888 - val_loss: -0.8901 - val_binary_accuracy: 0.9978 - val_iou: 0.8052 - val_dice_coef: 0.8907
# Epoch 111/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8962 - binary_accuracy: 0.9979 - iou: 0.8190 - dice_coef: 0.8965
# Epoch 00111: val_loss improved from -0.89606 to -0.90637, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 782ms/step - loss: -0.8962 - binary_accuracy: 0.9979 - iou: 0.8190 - dice_coef: 0.8965 - val_loss: -0.9064 - val_binary_accuracy: 0.9981 - val_iou: 0.8308 - val_dice_coef: 0.9068
# Epoch 112/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9049 - binary_accuracy: 0.9982 - iou: 0.8292 - dice_coef: 0.9048
# Epoch 00112: val_loss did not improve from -0.90637
# 89/88 [==============================] - 69s 776ms/step - loss: -0.9049 - binary_accuracy: 0.9982 - iou: 0.8292 - dice_coef: 0.9048 - val_loss: -0.8730 - val_binary_accuracy: 0.9977 - val_iou: 0.7837 - val_dice_coef: 0.8757
# Epoch 113/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9025 - binary_accuracy: 0.9980 - iou: 0.8284 - dice_coef: 0.9026
# Epoch 00113: val_loss did not improve from -0.90637
# 89/88 [==============================] - 69s 772ms/step - loss: -0.9025 - binary_accuracy: 0.9980 - iou: 0.8284 - dice_coef: 0.9026 - val_loss: -0.8966 - val_binary_accuracy: 0.9980 - val_iou: 0.8121 - val_dice_coef: 0.8950
# Epoch 114/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9108 - binary_accuracy: 0.9982 - iou: 0.8406 - dice_coef: 0.9109
# Epoch 00114: val_loss did not improve from -0.90637
# 89/88 [==============================] - 68s 769ms/step - loss: -0.9108 - binary_accuracy: 0.9982 - iou: 0.8406 - dice_coef: 0.9109 - val_loss: -0.9023 - val_binary_accuracy: 0.9980 - val_iou: 0.8278 - val_dice_coef: 0.9046
# Epoch 115/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9189 - binary_accuracy: 0.9984 - iou: 0.8517 - dice_coef: 0.9186
# Epoch 00115: val_loss did not improve from -0.90637
# 89/88 [==============================] - 70s 782ms/step - loss: -0.9189 - binary_accuracy: 0.9984 - iou: 0.8517 - dice_coef: 0.9186 - val_loss: -0.9029 - val_binary_accuracy: 0.9981 - val_iou: 0.8199 - val_dice_coef: 0.8999
# Epoch 116/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9063 - binary_accuracy: 0.9981 - iou: 0.8325 - dice_coef: 0.9062
# Epoch 00116: val_loss did not improve from -0.90637
# 89/88 [==============================] - 69s 772ms/step - loss: -0.9063 - binary_accuracy: 0.9981 - iou: 0.8325 - dice_coef: 0.9062 - val_loss: -0.8994 - val_binary_accuracy: 0.9980 - val_iou: 0.8215 - val_dice_coef: 0.9010
# Epoch 117/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9128 - binary_accuracy: 0.9983 - iou: 0.8456 - dice_coef: 0.9132
# Epoch 00117: val_loss did not improve from -0.90637
# 89/88 [==============================] - 69s 774ms/step - loss: -0.9128 - binary_accuracy: 0.9983 - iou: 0.8456 - dice_coef: 0.9132 - val_loss: -0.8961 - val_binary_accuracy: 0.9980 - val_iou: 0.8132 - val_dice_coef: 0.8958
# Epoch 118/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9126 - binary_accuracy: 0.9983 - iou: 0.8453 - dice_coef: 0.9129
# Epoch 00118: val_loss did not improve from -0.90637
# 89/88 [==============================] - 69s 776ms/step - loss: -0.9126 - binary_accuracy: 0.9983 - iou: 0.8453 - dice_coef: 0.9129 - val_loss: -0.9028 - val_binary_accuracy: 0.9980 - val_iou: 0.8260 - val_dice_coef: 0.9035
# Epoch 119/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9158 - binary_accuracy: 0.9984 - iou: 0.8493 - dice_coef: 0.9158
# Epoch 00119: val_loss improved from -0.90637 to -0.90774, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 791ms/step - loss: -0.9158 - binary_accuracy: 0.9984 - iou: 0.8493 - dice_coef: 0.9158 - val_loss: -0.9077 - val_binary_accuracy: 0.9980 - val_iou: 0.8386 - val_dice_coef: 0.9111
# Epoch 120/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9012 - binary_accuracy: 0.9981 - iou: 0.8264 - dice_coef: 0.9015
# Epoch 00120: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 770ms/step - loss: -0.9012 - binary_accuracy: 0.9981 - iou: 0.8264 - dice_coef: 0.9015 - val_loss: -0.8864 - val_binary_accuracy: 0.9979 - val_iou: 0.7962 - val_dice_coef: 0.8848
# Epoch 121/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9102 - binary_accuracy: 0.9982 - iou: 0.8406 - dice_coef: 0.9104
# Epoch 00121: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 773ms/step - loss: -0.9102 - binary_accuracy: 0.9982 - iou: 0.8406 - dice_coef: 0.9104 - val_loss: -0.9011 - val_binary_accuracy: 0.9981 - val_iou: 0.8179 - val_dice_coef: 0.8982
# Epoch 122/150
# 89/88 [==============================] - ETA: 0s - loss: -0.8961 - binary_accuracy: 0.9979 - iou: 0.8184 - dice_coef: 0.8963
# Epoch 00122: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 778ms/step - loss: -0.8961 - binary_accuracy: 0.9979 - iou: 0.8184 - dice_coef: 0.8963 - val_loss: -0.8628 - val_binary_accuracy: 0.9970 - val_iou: 0.7574 - val_dice_coef: 0.8593
# Epoch 123/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9094 - binary_accuracy: 0.9982 - iou: 0.8370 - dice_coef: 0.9094
# Epoch 00123: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 771ms/step - loss: -0.9094 - binary_accuracy: 0.9982 - iou: 0.8370 - dice_coef: 0.9094 - val_loss: -0.9070 - val_binary_accuracy: 0.9981 - val_iou: 0.8286 - val_dice_coef: 0.9053
# Epoch 124/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9154 - binary_accuracy: 0.9983 - iou: 0.8493 - dice_coef: 0.9156
# Epoch 00124: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 776ms/step - loss: -0.9154 - binary_accuracy: 0.9983 - iou: 0.8493 - dice_coef: 0.9156 - val_loss: -0.8981 - val_binary_accuracy: 0.9979 - val_iou: 0.8214 - val_dice_coef: 0.9005
# Epoch 125/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9206 - binary_accuracy: 0.9984 - iou: 0.8555 - dice_coef: 0.9208
# Epoch 00125: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 771ms/step - loss: -0.9206 - binary_accuracy: 0.9984 - iou: 0.8555 - dice_coef: 0.9208 - val_loss: -0.9073 - val_binary_accuracy: 0.9981 - val_iou: 0.8268 - val_dice_coef: 0.9036
# Epoch 126/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9187 - binary_accuracy: 0.9984 - iou: 0.8519 - dice_coef: 0.9185
# Epoch 00126: val_loss did not improve from -0.90774
# 89/88 [==============================] - 69s 773ms/step - loss: -0.9187 - binary_accuracy: 0.9984 - iou: 0.8519 - dice_coef: 0.9185 - val_loss: -0.9016 - val_binary_accuracy: 0.9982 - val_iou: 0.8228 - val_dice_coef: 0.9017
# Epoch 127/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9199 - binary_accuracy: 0.9984 - iou: 0.8576 - dice_coef: 0.9201
# Epoch 00136: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 777ms/step - loss: -0.9199 - binary_accuracy: 0.9984 - iou: 0.8576 - dice_coef: 0.9201 - val_loss: -0.9051 - val_binary_accuracy: 0.9981 - val_iou: 0.8192 - val_dice_coef: 0.8919
# Epoch 137/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9214 - binary_accuracy: 0.9984 - iou: 0.8581 - dice_coef: 0.9215
# Epoch 00137: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 776ms/step - loss: -0.9214 - binary_accuracy: 0.9984 - iou: 0.8581 - dice_coef: 0.9215 - val_loss: -0.9075 - val_binary_accuracy: 0.9981 - val_iou: 0.8359 - val_dice_coef: 0.9096
# Epoch 138/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9261 - binary_accuracy: 0.9985 - iou: 0.8632 - dice_coef: 0.9259
# Epoch 00138: val_loss did not improve from -0.91223
# 89/88 [==============================] - 68s 767ms/step - loss: -0.9261 - binary_accuracy: 0.9985 - iou: 0.8632 - dice_coef: 0.9259 - val_loss: -0.9013 - val_binary_accuracy: 0.9980 - val_iou: 0.8228 - val_dice_coef: 0.9018
# Epoch 139/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9184 - binary_accuracy: 0.9983 - iou: 0.8540 - dice_coef: 0.9185
# Epoch 00139: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 775ms/step - loss: -0.9184 - binary_accuracy: 0.9983 - iou: 0.8540 - dice_coef: 0.9185 - val_loss: -0.9087 - val_binary_accuracy: 0.9981 - val_iou: 0.8400 - val_dice_coef: 0.9121
# Epoch 140/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9212 - binary_accuracy: 0.9984 - iou: 0.8585 - dice_coef: 0.9214
# Epoch 00140: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 777ms/step - loss: -0.9212 - binary_accuracy: 0.9984 - iou: 0.8585 - dice_coef: 0.9214 - val_loss: -0.9101 - val_binary_accuracy: 0.9981 - val_iou: 0.8394 - val_dice_coef: 0.9119
# Epoch 141/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9235 - binary_accuracy: 0.9985 - iou: 0.8626 - dice_coef: 0.9235
# Epoch 00141: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 773ms/step - loss: -0.9235 - binary_accuracy: 0.9985 - iou: 0.8626 - dice_coef: 0.9235 - val_loss: -0.9099 - val_binary_accuracy: 0.9982 - val_iou: 0.8422 - val_dice_coef: 0.9132
# Epoch 142/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9251 - binary_accuracy: 0.9985 - iou: 0.8638 - dice_coef: 0.9252
# Epoch 00142: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 771ms/step - loss: -0.9251 - binary_accuracy: 0.9985 - iou: 0.8638 - dice_coef: 0.9252 - val_loss: -0.9090 - val_binary_accuracy: 0.9980 - val_iou: 0.8299 - val_dice_coef: 0.9062
# Epoch 143/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9224 - binary_accuracy: 0.9984 - iou: 0.8580 - dice_coef: 0.9225
# Epoch 00143: val_loss did not improve from -0.91223
# 89/88 [==============================] - 69s 777ms/step - loss: -0.9224 - binary_accuracy: 0.9984 - iou: 0.8580 - dice_coef: 0.9225 - val_loss: -0.9018 - val_binary_accuracy: 0.9981 - val_iou: 0.8183 - val_dice_coef: 0.8993
# Epoch 144/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9235 - binary_accuracy: 0.9985 - iou: 0.8634 - dice_coef: 0.9237
# Epoch 00144: val_loss improved from -0.91223 to -0.91356, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 783ms/step - loss: -0.9235 - binary_accuracy: 0.9985 - iou: 0.8634 - dice_coef: 0.9237 - val_loss: -0.9136 - val_binary_accuracy: 0.9982 - val_iou: 0.8482 - val_dice_coef: 0.9168
# Epoch 145/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9270 - binary_accuracy: 0.9986 - iou: 0.8681 - dice_coef: 0.9272
# Epoch 00145: val_loss did not improve from -0.91356
# 89/88 [==============================] - 68s 768ms/step - loss: -0.9270 - binary_accuracy: 0.9986 - iou: 0.8681 - dice_coef: 0.9272 - val_loss: -0.9105 - val_binary_accuracy: 0.9981 - val_iou: 0.8432 - val_dice_coef: 0.9139
# Epoch 146/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9247 - binary_accuracy: 0.9986 - iou: 0.8673 - dice_coef: 0.9250
# Epoch 00146: val_loss did not improve from -0.91356
# 89/88 [==============================] - 69s 774ms/step - loss: -0.9247 - binary_accuracy: 0.9986 - iou: 0.8673 - dice_coef: 0.9250 - val_loss: -0.9081 - val_binary_accuracy: 0.9981 - val_iou: 0.8335 - val_dice_coef: 0.9077
# Epoch 147/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9263 - binary_accuracy: 0.9985 - iou: 0.8673 - dice_coef: 0.9266
# Epoch 00147: val_loss improved from -0.91356 to -0.91877, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 70s 787ms/step - loss: -0.9263 - binary_accuracy: 0.9985 - iou: 0.8673 - dice_coef: 0.9266 - val_loss: -0.9188 - val_binary_accuracy: 0.9983 - val_iou: 0.8397 - val_dice_coef: 0.9104
# Epoch 148/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9266 - binary_accuracy: 0.9986 - iou: 0.8671 - dice_coef: 0.9265
# Epoch 00148: val_loss did not improve from -0.91877
# 89/88 [==============================] - 69s 773ms/step - loss: -0.9266 - binary_accuracy: 0.9986 - iou: 0.8671 - dice_coef: 0.9265 - val_loss: -0.9061 - val_binary_accuracy: 0.9981 - val_iou: 0.8166 - val_dice_coef: 0.8952
# Epoch 149/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9257 - binary_accuracy: 0.9985 - iou: 0.8661 - dice_coef: 0.9258
# Epoch 00149: val_loss did not improve from -0.91877
# 89/88 [==============================] - 69s 772ms/step - loss: -0.9257 - binary_accuracy: 0.9985 - iou: 0.8661 - dice_coef: 0.9258 - val_loss: -0.9128 - val_binary_accuracy: 0.9982 - val_iou: 0.8468 - val_dice_coef: 0.9161
# Epoch 150/150
# 89/88 [==============================] - ETA: 0s - loss: -0.9275 - binary_accuracy: 0.9986 - iou: 0.8675 - dice_coef: 0.9276
# Epoch 00150: val_loss did not improve from -0.91877
# 89/88 [==============================] - 69s 774ms/step - loss: -0.9275 - binary_accuracy: 0.9986 - iou: 0.8675 - dice_coef: 0.9276 - val_loss: -0.9127 - val_binary_accuracy: 0.9984 - val_iou: 0.8411 - val_dice_coef: 0.9127

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']
plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
model = load_model('unet_brain_mri_seg.hdf5', custom_objects={'dice_coef_loss': dice_coef_loss, 'iou': iou, 'dice_coef': dice_coef})

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 13/12 [===============================] - 6s 439ms/step - loss: -0.9040 - binary_accuracy: 0.9981 - iou: 0.8228 - dice_coef: 0.9020
# Test lost:  -0.904030978679657
# Test IOU:  0.9981186985969543
# Test Dice Coefficent:  0.822847306728363

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
